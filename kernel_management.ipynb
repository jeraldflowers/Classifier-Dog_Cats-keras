# %% [markdown]
# <a href="https://colab.research.google.com/github/jeraldflowers/Classifier-Dog_Cats-keras/blob/main/kernel_management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage as nd
from skimage import io, color

# %%
img = io.imread('/content/yo.png')

plt.imshow(img)

# %%
img_gray = color.rgb2gray(img)

img_gray.shape
# Out:
# (428, 437)

# %%
plt.imshow(img_gray)

# %%
kernel = np.array([[-1, 0, 1],
                   [-1, 0, 1],
                   [-1, 0, 1]])

# %%
kernel
# Out:
# array([[-1,  0,  1],
#        [-1,  0,  1],
#        [-1,  0,  1]])

# %%
img_new = nd.convolve(img_gray, kernel)

# %%
from matplotlib import cm
fig, axes = plt.subplots(1, 2, figsize=(15, 10))
axes[0].imshow(img_gray, cmap=plt.cm.gray)
axes[0].set_title('Original')
axes[0].axis('off')

axes[1].imshow(img_new, cmap=plt.cm.gray)
axes[1].set_title('Convolution')
axes[1].axis('off')
# Out:
# (-0.5, 436.5, 427.5, -0.5)
