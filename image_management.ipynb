# %% [markdown]
# <a href="https://colab.research.google.com/github/jeraldflowers/Classifier-Dog_Cats-keras/blob/main/image_management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io

# %%
im = io.imread('/content/Mara.jpeg')
im
# Out:
# array([[[ 98, 111, 101],
#         [103, 117, 104],
#         [ 98, 112,  97],
#         ...,
#         [181, 184, 189],
#         [180, 183, 188],
#         [180, 183, 188]],
#
#        [[ 97, 111,  98],
#         [103, 117, 104],
#         [ 98, 112,  97],
#         ...,
#         [181, 184, 189],
#         [180, 183, 188],
#         [180, 183, 188]],
#
#        [[ 96, 110,  97],
#         [103, 117, 102],
#         [101, 115,  98],
#         ...,
#         [180, 183, 188],
#         [180, 183, 188],
#         [180, 183, 188]],
#
#        ...,
#
#        [[ 68,  82,  21],
#         [ 65,  79,  18],
#         [ 81,  97,  32],
#         ...,
#         [ 73,  99,  26],
#         [117, 143,  70],
#         [108, 134,  61]],
#
#        [[ 75,  83,  36],
#         [103, 113,  60],
#         [ 68,  82,  20],
#         ...,
#         [ 98, 126,  52],
#         [ 33,  61,   0],
#         [ 69,  97,  23]],
#
#        [[ 90,  96,  58],
#         [ 87,  95,  48],
#         [ 50,  64,   3],
# ...

# %%
im.shape
# Out:
# (800, 600, 3)

# %%
plt.imshow(im)

# %%
r = im[:,:,0]
g = im[:,:,1]
b = im[:,:,2]

# %%
plt.imshow(r.T, cmap='gray')

# %%
r.shape
aux_dim = np.zeros([800,600])

# %%
red = np.dstack((r, aux_dim, aux_dim)).astype(np.uint8)
green = np.dstack((aux_dim, g, aux_dim)).astype(np.uint8)
blue = np.dstack((aux_dim, aux_dim, b)).astype(np.uint8)

# %%
plt.imshow(red)

# %%
plt.imshow(green)

# %%
im_neg_pos = 255 - im
im32 = (im//32) * 32
im128 = (im//128) * 128

plt.imshow(im_neg_pos)

# %%
plt.imshow(im128)

# %%
plt.imshow(im[270:530, 150:400])
